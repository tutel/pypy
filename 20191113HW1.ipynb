# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sympy as sp

# %%
df = pd.read_html("https://zh.wikipedia.org/wiki/%E5%90%84%E5%9B%BD%E4%BA%BA%E5%9D%87%E6%B1%BD%E8%BD%A6%E6%8B%A5%E6%9C%89%E9%87%8F%E5%88%97%E8%A1%A8")

# %%
df = df[1]

# %%
df
# Out:
#       排名     国家/地区  每千人汽车拥有量              总计          注释
# 0      1      圣马力诺      1263             NaN         [1]
# 1      2        美國       910  255,009,283[2]     2017[2]
# 2      3       摩納哥       899             NaN         [1]
# 3      4       新西蘭       774         3600000     2017[3]
# 4      5     列支敦斯登       750             NaN  2014[1][4]
# 5      6        冰島       745             NaN         [1]
# 6      7      澳大利亚       740             NaN     2017[5]
# 7      8       卢森堡       739             NaN         [1]
# 8      9       馬爾他       693             NaN         [1]
# 9     10       義大利       679             NaN         [1]
# 10    11        關島       677             NaN     2014[6]
# 11    12       加拿大       662   23,553,604[7]        2016
# 12    13        芬兰       612             NaN     2011[1]
# 13    14       西班牙       593             NaN         [1]
# 14    15        日本       591   77,657,517[8]     2017[1]
# ...

# %%
df.sort_values(by =["总计"], ascending=False)
# Out:
#       排名     国家/地区  每千人汽车拥有量              总计            注释
# 171  171      衣索比亞         8          850000          2017
# 14    15        日本       591   77,657,517[8]       2017[1]
# 53    53        臺灣       333   7,842,423[20]      2016[20]
# 59    59      羅馬尼亞       305         5996377      2017[23]
# 133  133        印度        50  55,725,543[43]          2015
# 85    85      亞美尼亞       167          489346     2018 [35]
# 55    55       俄羅斯       324        46887145      2017[22]
# 19    20        德國       572        46332000           [1]
# 21    22        瑞士       543         4524029      2016[12]
# 18    19        法國       578        38148000      2014[10]
# 3      4       新西蘭       774         3600000       2017[3]
# 67    67        巴西       249        35601099      2016[28]
# 20    21        波蘭       567        35450000      2011[11]
# 33    34        英國       519        33735000       2010[1]
# 45    46       以色列       384   3,373,139[18]      2017[19]
# ...
