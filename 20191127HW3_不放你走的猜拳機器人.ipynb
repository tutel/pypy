# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from IPython.display import YouTubeVideo,display

# %%
from numpy.random import randint

# %%
txt = ''
p = "OAO"
print("你要猜贏我才能離開這個程式")
while txt != "win":
    L = ["剪刀","石頭","布"]
    a = randint(0,3)
    pl = input("剪刀石頭布\n")
    if pl == "剪刀":
        p = 0
    elif pl == "石頭":
        p = 1
    elif pl == "布":
        p = 2
    else:
        print("猜拳?")
        continue
    
    if p == a:
        print(f"你出{pl}電腦出{L[a]},所以平手")
    elif p - a == 1 or p == 0 and a == 2:
        print(f"你出{pl}電腦出{L[a]},所以你贏了")
        print("可惡TAT")
        vd = YouTubeVideo("dNqJx8GJ3BY")
        display(vd)
        txt = "win"
        
    else:
        print(f"你出{pl}電腦出{L[a]},所以我贏了")
        print("懲罰你聽How哥的歌聲")
        vd = YouTubeVideo("YXb800paJhw")
        display(vd)
        txt = "Lose"
# Out:
# 你要猜贏我才能離開這個程式
# 剪刀石頭布
# 石頭
# 你出石頭電腦出石頭,所以平手
# 剪刀石頭布
# 石頭
# 你出石頭電腦出布,所以我贏了
# 懲罰你聽How哥的歌聲
# 剪刀石頭布
# 剪刀
# 你出剪刀電腦出布,所以你贏了
# 可惡TAT
